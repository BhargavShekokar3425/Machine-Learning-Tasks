# %% [markdown]
# This is a Credit Card Fraud prediction system
#
# **Work Flow**
#
# Credit Card data -> Data pre processing -> Data analysis -> Train test split -> Logistic Regression Model

# %% [markdown]
# Importing the dependencies

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
#load the dataset in DF
credit_data = pd.read_csv('creditcard.csv')

# %%
credit_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
credit_data['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
credit_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# This dataset is highly unbalanced

# %% [markdown]
# 0--> Normal Transaction
#
# 1--> Fraudulent transaction

# %%
#separating the data for analysis
legit = credit_data[credit_data.Class == 0]
fraud = credit_data[credit_data.Class == 1]

# %%
print(legit.shape,fraud.shape)
# Out:
# (284315, 31) (492, 31)

# %%
#statisctical measures of the data
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
# compare the values for both transactions
credit_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# Under sampling

# %% [markdown]
# Build a sample dataset containing similar distribution of normal transactions and Fraudulent Transaactions

# %% [markdown]
# Number of Fraudulent Transactions -> 492

# %% [markdown]
# We take random 492 data points from legit dataset and join it with fraud dataset to make it a good dataset for training

# %%
legit_sample =legit.sample(n=492)

# %% [markdown]
# Concatenating two Dataframes

# %%
new_data =pd.concat([legit_sample,fraud],axis=0)

# %%
new_data.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 42727    41219.0 -2.140119  0.191360 -0.199119  0.544156 -0.327941 -0.469120
# 12061    20912.0 -0.461802  1.005206  2.814234  2.193736  0.047832  1.101699
# 199671  133076.0 -2.170476 -1.342464  1.451034 -0.892342  2.395309  1.416637
# 168969  119462.0 -3.062189 -1.171786 -1.209979  0.237830  1.492392 -0.369274
# 132838   80137.0  1.221247  0.492915  0.047626  1.360042  0.061107 -0.450567
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 42727   0.651569  0.746109 -1.033838  ...  0.275733  0.437316 -0.148735
# 12061  -0.422002  0.374782  0.238277  ...  0.123298  0.545921 -0.375994
# 199671 -0.025842  0.513566  0.136623  ... -0.439668 -0.901572  0.821666
# 168969 -0.861669  0.116672 -0.278561  ...  1.347039  1.099412 -0.860328
# 132838  0.098962 -0.122637  0.308370  ... -0.341862 -0.738012 -0.066351
#
# ...

# %%
new_data.shape
# Out:
# (984, 31)

# %%
new_data['Class'].value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %% [markdown]
# Splitting of data

# %%
X = new_data.drop(columns='Class',axis=1)
Y = new_data['Class']

# %%
X
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 42727    41219.0 -2.140119  0.191360 -0.199119  0.544156 -0.327941 -0.469120
# 12061    20912.0 -0.461802  1.005206  2.814234  2.193736  0.047832  1.101699
# 199671  133076.0 -2.170476 -1.342464  1.451034 -0.892342  2.395309  1.416637
# 168969  119462.0 -3.062189 -1.171786 -1.209979  0.237830  1.492392 -0.369274
# 132838   80137.0  1.221247  0.492915  0.047626  1.360042  0.061107 -0.450567
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
Y
# Out:
# 42727     0
# 12061     0
# 199671    0
# 168969    0
# 132838    0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 984, dtype: int64

# %% [markdown]
# Train -test split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,stratify=Y,random_state=1,test_size=0.2)

# %%
X_train,X_test,Y_train,Y_test
# Out:
# (            Time         V1         V2         V3        V4         V5  \
#  244337  152310.0  -3.205672  -2.063761   0.604753  0.989665   3.495364
#  241254  150949.0  -2.423535   1.659093  -3.071421  2.588033   1.135791
#  42674    41194.0  -7.896886   5.381020  -8.451162  7.963928  -7.862419
#  6820      8614.0  -2.169929   3.639654  -4.508498  2.730668  -2.122693
#  252774  155965.0  -1.201398   4.864535  -8.328823  7.652399  -0.167445
#  ...          ...        ...        ...        ...       ...        ...
#  150660   93853.0  -6.185857   7.102985 -13.030455  8.010823  -7.885237
#  120664   75914.0  -2.109671  -0.014006   2.179852  0.446459  -0.299006
#  52584    45541.0  -1.519244   2.308492  -1.503599  2.064101  -1.000845
#  30496    35953.0  -4.844372   5.649439  -6.730396  5.252842  -4.409566
#  14211    25254.0 -17.275191  10.819665 -20.363886  6.046612 -13.465033
#
#                V6         V7         V8        V9  ...       V20       V21  \
# ...

# %% [markdown]
# Training your model : Logistic Regression

# %%
classifier = LogisticRegression()

# %%
classifier.fit(X_train,Y_train)
# Out:
# c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# Model Analyisis

# %%
#accuracy on training data
X_train_prediction = classifier.predict(X_train)
X_train_accuracy = accuracy_score(Y_train,X_train_prediction)
print("The accuracy score for training dataset is ",X_train_accuracy)


#accuracy on testing data
X_test_prediction = classifier.predict(X_test)
X_test_accuracy = accuracy_score(Y_test,X_test_prediction)
print("The accuracy score for testing dataset is ",X_test_accuracy)
# Out:
# The accuracy score for training dataset is  0.9466327827191868
# The accuracy score for testing dataset is  0.9086294416243654

# %% [markdown]
# Predictor System

# %%
input_data =(35953,-4.84437152213983,5.64943864783758,-6.73039574613665,5.25284201867297,-4.4095661499774,-1.74076745609347,-6.31169852901067,3.44916731253577,-5.41628435913526,-7.8335555711125,3.6573495649865,-7.7814479532704,1.50772042676786,-8.60475886835984,0.0105926875670707,-6.55397325691037,-12.6243936527694,-4.98990973846596,1.64541389333247,0.284555090358885,1.19488835625662,-0.845752531858704,0.190673885417928,-0.216443252531192,-0.325033100382822,-0.270327592956951,0.210214051535782,0.391854886292055,111.7)
input_data_np =np.asanyarray(input_data)
input_data_reshape = input_data_np.reshape(1,-1)
prediction = classifier.predict(input_data_reshape)

print(prediction[0])

if(prediction[0]==1):
    print("The transaction is fraudulent")
else:
    print("The transaction is legit")
# Out:
# 1
# The transaction is fraudulent
# c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
